# %%
import pandas as pd

# %%
df = pd.DataFrame.from_csv("home_data.csv")

# %%
df
# Out:
#                        date    price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000   221900         3       1.00         1180
# 6414100192  20141209T000000   538000         3       2.25         2570
# 5631500400  20150225T000000   180000         2       1.00          770
# 2487200875  20141209T000000   604000         4       3.00         1960
# 1954400510  20150218T000000   510000         3       2.00         1680
# 7237550310  20140512T000000  1225000         4       4.50         5420
# 1321400060  20140627T000000   257500         3       2.25         1715
# 2008000270  20150115T000000   291850         3       1.50         1060
# 2414600126  20150415T000000   229500         3       1.00         1780
# 3793500160  20150312T000000   323000         3       2.50         1890
# 1736800520  20150403T000000   662500         3       2.50         3560
# 9212900260  20140527T000000   468000         2       1.00         1160
# ...

# %%
import sklearn.linear_model as lm

# %%
x = df.iloc[:,:-1]

# %%
y = df.iloc[:,-1]

# %%
skm.fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8e3ab88443cc> in <module>()
# ----> 1 skm.fit(x, y)
#
# NameError: name 'skm' is not defined

# %%
skm = lm.LinearRegression()

# %%
skm.fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-8e3ab88443cc> in <module>()
# ----> 1 skm.fit(x, y)
#
# C:\Users\eskuratov\Anaconda2\envs\gl-env\lib\site-packages\sklearn\linear_model\base.pyc in fit(self, X, y, sample_weight)
#     425         n_jobs_ = self.n_jobs
#     426         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 427                          y_numeric=True, multi_output=True)
#     428
#     429         if ((sample_weight is not None) and np.atleast_1d(sample_weight).ndim > 1):
#
# C:\Users\eskuratov\Anaconda2\envs\gl-env\lib\site-packages\sklearn\utils\validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
df.price
# Out:
# id
# 7129300520     221900
# 6414100192     538000
# 5631500400     180000
# 2487200875     604000
# 1954400510     510000
# 7237550310    1225000
# 1321400060     257500
# 2008000270     291850
# 2414600126     229500
# 3793500160     323000
# 1736800520     662500
# 9212900260     468000
# 114101516      310000
# 6054650070     400000
# 1175000570     530000
# 9297300055     650000
# 1875500060     395000
# 6865200140     485000
# 16000397       189000
# 7983200060     230000
# 6300500875     385000
# 2524049179    2000000
# 7137970340     285000
# 8091400200     252700
# 3814700200     329000
# 1202000200     233000
# 1794500383     937000
# 3303700376     667000
# 5101402488     438000
# 1873100390     719000
#                ...
# 2025049203     399950
# 952006823      380000
# 3832050760     270000
# 2767604724     505000
# 6632300207     385000
# 2767600688     414500
# 7570050450     347500
# 7430200100    1222500
# 4140940150     572000
# 1931300412     475000
# ...

# %%
df.zipcode
# Out:
# id
# 7129300520    98178
# 6414100192    98125
# 5631500400    98028
# 2487200875    98136
# 1954400510    98074
# 7237550310    98053
# 1321400060    98003
# 2008000270    98198
# 2414600126    98146
# 3793500160    98038
# 1736800520    98007
# 9212900260    98115
# 114101516     98028
# 6054650070    98074
# 1175000570    98107
# 9297300055    98126
# 1875500060    98019
# 6865200140    98103
# 16000397      98002
# 7983200060    98003
# 6300500875    98133
# 2524049179    98040
# 7137970340    98092
# 8091400200    98030
# 3814700200    98030
# 1202000200    98002
# 1794500383    98119
# 3303700376    98112
# 5101402488    98115
# 1873100390    98052
#               ...
# 2025049203    98102
# 952006823     98116
# 3832050760    98042
# 2767604724    98107
# 6632300207    98125
# 2767600688    98117
# 7570050450    98038
# 7430200100    98074
# 4140940150    98178
# 1931300412    98103
# 8672200110    98056
# 5087900040    98042
# 1972201967    98103
# 7502800100    98059
# ...

# %%
df.head()
# Out:
#                        date   price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900         3       1.00         1180
# 6414100192  20141209T000000  538000         3       2.25         2570
# 5631500400  20150225T000000  180000         2       1.00          770
# 2487200875  20141209T000000  604000         4       3.00         1960
# 1954400510  20150218T000000  510000         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
# ...

# %%
df.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308350   0.525138     0.702035  0.089661  0.256794
# bedrooms       0.308350  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.525138  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living    0.702035  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.256794  0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006582   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.079532   0.187737     0.284611  0.074710  0.029444
# condition      0.036362  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.477600   0.685342     0.876597  0.183512  0.523885
# ...

# %%
df=df.drop(['price'],['sqft_living'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-7b3fd104c587> in <module>()
# ----> 1 df=df.drop(['price'],['sqft_living'],axis=1)
#
# TypeError: drop() got multiple values for keyword argument 'axis'

# %%
df=df.drop(['price','sqft_living'],axis=1)

# %%
df
# Out:
#                        date  bedrooms  bathrooms  sqft_lot  floors  \
# id
# 7129300520  20141013T000000         3       1.00      5650     1.0
# 6414100192  20141209T000000         3       2.25      7242     2.0
# 5631500400  20150225T000000         2       1.00     10000     1.0
# 2487200875  20141209T000000         4       3.00      5000     1.0
# 1954400510  20150218T000000         3       2.00      8080     1.0
# 7237550310  20140512T000000         4       4.50    101930     1.0
# 1321400060  20140627T000000         3       2.25      6819     2.0
# 2008000270  20150115T000000         3       1.50      9711     1.0
# 2414600126  20150415T000000         3       1.00      7470     1.0
# 3793500160  20150312T000000         3       2.50      6560     2.0
# 1736800520  20150403T000000         3       2.50      9796     1.0
# 9212900260  20140527T000000         2       1.00      6000     1.0
# 114101516   20140528T000000         3       1.00     19901     1.5
# ...

# %%
df.head()
# Out:
#                        date  bedrooms  bathrooms  sqft_lot  floors  \
# id
# 7129300520  20141013T000000         3       1.00      5650     1.0
# 6414100192  20141209T000000         3       2.25      7242     2.0
# 5631500400  20150225T000000         2       1.00     10000     1.0
# 2487200875  20141209T000000         4       3.00      5000     1.0
# 1954400510  20150218T000000         3       2.00      8080     1.0
#
#             waterfront  view  condition  grade  sqft_above  sqft_basement  \
# id
# 7129300520           0     0          3      7        1180              0
# 6414100192           0     0          3      7        2170            400
# 5631500400           0     0          3      6         770              0
# 2487200875           0     0          5      7        1050            910
# 1954400510           0     0          3      8        1680              0
#
#             yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# id
# ...

# %%
df
# Out:
#                        date    price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000   221900         3       1.00         1180
# 6414100192  20141209T000000   538000         3       2.25         2570
# 5631500400  20150225T000000   180000         2       1.00          770
# 2487200875  20141209T000000   604000         4       3.00         1960
# 1954400510  20150218T000000   510000         3       2.00         1680
# 7237550310  20140512T000000  1225000         4       4.50         5420
# 1321400060  20140627T000000   257500         3       2.25         1715
# 2008000270  20150115T000000   291850         3       1.50         1060
# 2414600126  20150415T000000   229500         3       1.00         1780
# 3793500160  20150312T000000   323000         3       2.50         1890
# 1736800520  20150403T000000   662500         3       2.50         3560
# 9212900260  20140527T000000   468000         2       1.00         1160
# ...

# %%
df=df.drop(['price','sqft_living'],axis=1) date	price	bedrooms	bathrooms	sqft_living	sqft_lot	floors	waterfront	view	condition	grade	sqft_above	sqft_basement	yr_built	yr_renovated	zipcode	lat	long	sqft_living15	sqft_lot15
# Out:
#   File "<ipython-input-21-edc753904a0d>", line 1
#     df=df.drop(['price','sqft_living'],axis=1) date	price	bedrooms	bathrooms	sqft_living	sqft_lot	floors	waterfront	view	condition	grade	sqft_above	sqft_basement	yr_built	yr_renovated	zipcode	lat	long	sqft_living15	sqft_lot15
#                                                   ^
# SyntaxError: invalid syntax

# %%
df=df.drop(['date','bedrooms','bathrooms','sqft_lot','floors','waterfront','view,condition'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-6fd01ce12ea6> in <module>()
# ----> 1 df=df.drop(['date','bedrooms','bathrooms','sqft_lot','floors','waterfront','view,condition'],axis=1)
#
# C:\Users\eskuratov\Anaconda2\envs\gl-env\lib\site-packages\pandas\core\generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    1871                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1872             else:
# -> 1873                 new_axis = axis.drop(labels, errors=errors)
#    1874             dropped = self.reindex(**{axis_name: new_axis})
#    1875             try:
#
# C:\Users\eskuratov\Anaconda2\envs\gl-env\lib\site-packages\pandas\indexes\base.pyc in drop(self, labels, errors)
#    2964             if errors != 'ignore':
#    2965                 raise ValueError('labels %s not contained in axis' %
# ...

# %%
df=df.drop(['date','bedrooms'],axis=1)

# %%
df=df.drop(['bathrooms','sqft_lot'],axis=1)

# %%
df=df.drop(['sqft_living15','sqft_lot15'],axis=1)

# %%
df
# Out:
#               price  sqft_living  view  condition  grade  sqft_above  \
# id
# 7129300520   221900         1180     0          3      7        1180
# 6414100192   538000         2570     0          3      7        2170
# 5631500400   180000          770     0          3      6         770
# 2487200875   604000         1960     0          5      7        1050
# 1954400510   510000         1680     0          3      8        1680
# 7237550310  1225000         5420     0          3     11        3890
# 1321400060   257500         1715     0          3      7        1715
# 2008000270   291850         1060     0          3      7        1060
# 2414600126   229500         1780     0          3      7        1050
# 3793500160   323000         1890     0          3      7        1890
# 1736800520   662500         3560     0          3      8        1860
# 9212900260   468000         1160     0          4      7         860
# ...

# %%
df
# Out:
#               price  sqft_living
# id
# 7129300520   221900         1180
# 6414100192   538000         2570
# 5631500400   180000          770
# 2487200875   604000         1960
# 1954400510   510000         1680
# 7237550310  1225000         5420
# 1321400060   257500         1715
# 2008000270   291850         1060
# 2414600126   229500         1780
# 3793500160   323000         1890
# 1736800520   662500         3560
# 9212900260   468000         1160
# 114101516    310000         1430
# 6054650070   400000         1370
# 1175000570   530000         1810
# 9297300055   650000         2950
# 1875500060   395000         1890
# 6865200140   485000         1600
# 16000397     189000         1200
# 7983200060   230000         1250
# 6300500875   385000         1620
# 2524049179  2000000         3050
# 7137970340   285000         2270
# 8091400200   252700         1070
# 3814700200   329000         2450
# 1202000200   233000         1710
# 1794500383   937000         2450
# ...

# %%
trg=df

# %%
trg
# Out:
#               price  sqft_living
# id
# 7129300520   221900         1180
# 6414100192   538000         2570
# 5631500400   180000          770
# 2487200875   604000         1960
# 1954400510   510000         1680
# 7237550310  1225000         5420
# 1321400060   257500         1715
# 2008000270   291850         1060
# 2414600126   229500         1780
# 3793500160   323000         1890
# 1736800520   662500         3560
# 9212900260   468000         1160
# 114101516    310000         1430
# 6054650070   400000         1370
# 1175000570   530000         1810
# 9297300055   650000         2950
# 1875500060   395000         1890
# 6865200140   485000         1600
# 16000397     189000         1200
# 7983200060   230000         1250
# 6300500875   385000         1620
# 2524049179  2000000         3050
# 7137970340   285000         2270
# 8091400200   252700         1070
# 3814700200   329000         2450
# 1202000200   233000         1710
# 1794500383   937000         2450
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-42-0dc09eb70157> in <module>()
# ----> 1 from sklearn import train_test_split
#
# ImportError: cannot import name train_test_split

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-43-139cc3505715> in <module>()
# ----> 1 from sklearn.model_selection import train_test_split
#
# ImportError: No module named model_selection

# %%
import sklearn as sk

# %%
X_train, X_test, y_train, y_test = train_test_split(df,df, test_size=0.33, random_state=42)

# %%
sk.version()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-23615720d168> in <module>()
# ----> 1 sk.version()
#
# AttributeError: 'module' object has no attribute 'version'

# %%
X_train, X_test, y_train, y_test = sk.model_selection.train_test_split(df,df, test_size=0.33, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-f08079ece4aa> in <module>()
# ----> 1 X_train, X_test, y_train, y_test = sk.model_selection.train_test_split(df,df, test_size=0.33, random_state=42)
#
# AttributeError: 'module' object has no attribute 'model_selection'

# %%
from sklearn.cross_validation import train_test_split

# %%
X_train
# Out:
#               price  sqft_living
# id
# 2653000005   840000         2600
# 1657310170   302000         2140
# 2425700022   425000         1730
# 6181400470   215000         2130
# 2206500300   565000         1910
# 7550800736   600000         1180
# 9477001280   425000         1520
# 6633900050   575000         1750
# 8731981410   274000         2090
# 5423600100   604000         2580
# 8923600185   800000         2760
# 4014400381   495000         2656
# 7751800115   425000         1390
# 3216900100   315000         1880
# 8121100600   525000         1640
# 104550580    260000         1990
# 5015001452   950000         2280
# 3584900090   577000         1760
# 3275910020   340000         2181
# 7853340490   386000         1620
# 2725069162   772000         2990
# 5525400300   619420         2450
# 3566800125   425000         1250
# 8099900040   519950         2440
# 6821600300   886000         2380
# 9542830050   355000         2150
# 5631500213   342400         1180
# ...

# %%
regr=LinearRegression()

# %%
regr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
import matplotlib.pyplot as plt

# %%
print('Coefficients: \n', regr.coef_)
# Out:
# ('Coefficients: \n', array([[  1.00000000e+00,   6.70176731e-16],
#        [  1.01644600e-18,   1.00000000e+00]]))

# %%
plt.scatter(X_test,y_test,  color='black')

# %%
plt.plot(X_test, regr.predict(X_test), color='blue',
         linewidth=3)

# %%
plt.xticks(())
plt.yticks(())

plt.show()

# %%
from scipy import stats

# %%
slope,intercept,r_value,p_value,std_err=stats.linregress(X_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-7bad29c8b509> in <module>()
# ----> 1 slope,intercept,r_value,p_value,std_err=stats.linregress(X_test,y_test)
#
# C:\Users\eskuratov\Anaconda2\envs\gl-env\lib\site-packages\scipy\stats\_stats_mstats_common.pyc in linregress(x, y)
#      77
#      78     # average sum of squares:
# ---> 79     ssxm, ssxym, ssyxm, ssym = np.cov(x, y, bias=1).flat
#      80     r_num = ssxym
#      81     r_den = np.sqrt(ssxm * ssym)
#
# ValueError: too many values to unpack

# %%
r_v
